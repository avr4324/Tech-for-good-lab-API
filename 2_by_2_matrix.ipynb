# %%
from IPython.display import clear_output
# !pip install openai # import the GPT API
from google.colab import userdata # import the secret key
clear_output()

# %%
import openai

# Defining an API_call function
def API_call(model, OPENAI_KEY, prompt, system_prompt=''):

    openai.api_key = OPENAI_KEY

    response = openai.ChatCompletion.create(
        model=model,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": prompt}
        ]
    )
    return response['choices'][0]['message']['content']

# %%
# Key: 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
# Add your OPENAI_Key to the secrets tab (looks like a key) on the left toolbar on Google Colab. Make you sure you enable Notebook Access!
OPENAI_API_KEY = userdata.get('OPENAI_KEY')

# Not Recommended: you could also paste your key directly here but it isn't as secure: OPENAI_API_KEY = your_key)

# %%
prompt = '''A 2x2 matrix helps in exploring the problem space by comparing two variables that are critical for understanding the needs and behaviors of elderly patients in accessing health information. For this matrix, consider the following two axes:

X-axis: Level of Technological Proficiency (Low to High)
Y-axis: Degree of Health Literacy (Low to High)
This matrix will help in identifying specific user segments and tailoring solutions to meet their unique needs.

Quadrant 1: Low Tech / Low Health Literacy
Quadrant 2: High Tech / Low Health Literacy
Quadrant 3: Low Tech / High Health Literacy
Quadrant 4: High Tech / High Health Literacy

It is your turn to add a post-it note using green hat for quadrant 1.

Generate 10 ideas for each quadrant'''

# %%
system_prompt = f'''You are part of a team brainstorming session aimed at generating ideas for ways to make medical information more accessible and engaging for elderly patients who may not be tech-savvy. This is the first stage where people are freely throwing out ideas. Later, we will narrow these ideas down. When it's your turn, you should add one new post-it note onto the collective brainstorming whiteboard, describing an idea or direction for addressing cyberbullying. You can also describe the post-it note to your team members.
Additionally, you will be asked to wear a particular "hat" for brainstorming:
GREEN HAT: You focus on creatively exploring the design space, aiming to help the team consider areas that have not yet been explored. You are not afraid to suggest ideas that might seem unconventional or impractical if they could inspire new thoughts.
Each time, you will be asked to brainstorm with a particular hat in mind. You should respond in the following format:
- Post-it note: [A concise phrase capturing the idea or direction worth exploring. It should be brief enough to fit on a post-it note, so it needs to be just a short, concise phrase.]
- Description: [A longer description explaining your post-it note to the rest of the team. This can be a few sentences or even paragraphs. If using the yellow hat, describe the past idea you're building on. If using the white hat, describe the objective information you're considering. If using the green hat, explain the design space you're exploring. If using the black hat, outline the potential problems or obstacles. If using the red hat, express your emotional reactions or intuitions. If using the blue hat, organize the discussion and summarize key points.]
Note: To ensure a respectful and constructive brainstorming environment, please focus on the ideas and avoid any negative comments or personal attacks on others' contributions. We aim to foster a positive and inclusive atmosphere for all participants.
{prompt}'''

# %%
print(prompt)
# Out:
# A 2x2 matrix helps in exploring the problem space by comparing two variables that are critical for understanding the needs and behaviors of elderly patients in accessing health information. For this matrix, consider the following two axes:
#
# X-axis: Level of Technological Proficiency (Low to High)
# Y-axis: Degree of Health Literacy (Low to High)
# This matrix will help in identifying specific user segments and tailoring solutions to meet their unique needs.
#
# Quadrant 1: Low Tech / Low Health Literacy
# Quadrant 2: High Tech / Low Health Literacy
# Quadrant 3: Low Tech / High Health Literacy
# Quadrant 4: High Tech / High Health Literacy
#
# It is your turn to add a post-it note using green hat for quadrant 1.
#
# Generate 10 ideas for each quadrant

# %%
print(system_prompt)
# Out:
# You are part of a team brainstorming session aimed at generating ideas for ways to make medical information more accessible and engaging for elderly patients who may not be tech-savvy. This is the first stage where people are freely throwing out ideas. Later, we will narrow these ideas down. When it's your turn, you should add one new post-it note onto the collective brainstorming whiteboard, describing an idea or direction for addressing cyberbullying. You can also describe the post-it note to your team members.
# Additionally, you will be asked to wear a particular "hat" for brainstorming:
# GREEN HAT: You focus on creatively exploring the design space, aiming to help the team consider areas that have not yet been explored. You are not afraid to suggest ideas that might seem unconventional or impractical if they could inspire new thoughts.
# Each time, you will be asked to brainstorm with a particular hat in mind. You should respond in the following format:
# ...

# %%
pip install openai==0.28

# %%
# Current GPT models
# If you are using GPT-4, I would recommend GPT 4o "gpt4-o"
models = {"gpt3.5": "gpt-3.5-turbo-0125", "gpt4": "gpt-4-0125-preview", "gpt4-o": "gpt-4o-2024-05-13", "gpt4-o-mini":"gpt-4o-mini-2024-07-18", "gpt4-turbo": "gpt-4-turbo-2024-04-09"}

model = models["gpt4-o"]

# Here we actually call the GPT API
response = API_call(model, OPENAI_API_KEY, system_prompt)

# %%
print(response)
# Out:
# ### Quadrant 1: Low Tech / Low Health Literacy
#
# #### Idea 1
# - Post-it note: **Visual Storytelling**
# - Description: Utilize visuals like comics or illustrated stories to explain medical information. These can be provided in printed booklets. Visuals are often easier to understand than text-heavy documents, particularly for those who struggle with both technology and health literacy.
#
# #### Idea 2
# - Post-it note: **Interactive Voice Response Systems**
# - Description: Deploy a phone-based interactive voice response system that uses natural language processing to speak and understand simple questions about health conditions and treatments.
#
# #### Idea 3
# - Post-it note: **Community Health Classes**
# - Description: Organize free, community-based health education classes led by healthcare providers, designed to be easily understandable and engaging with interactive elements and hands-on learning.
#
# #### Idea 4
# - Post-it note: **Health Ambassadors Program**
# ...

# %%
texts = [
    {

        "Post-it note": "Audio Guides",
        "Description": "Create easy-to-understand audio guides that can explain medical information in a clear and soothing voice. These could be provided in multiple languages."
    },

    {

        "Post-it note": "Picture-Based Instructions",
        "Description": "Use visual aids and picture-based instructions to explain medical procedures, medications, and health-related tasks."
    },

    {
        "Post-it note": "Easy-to-Read Brochures",
        "Description": "Design brochures with large fonts and simple language to explain medical information."
    },

    {
        "Post-it note": "Community Workshops",
        "Description": "Hold in-person workshops at community centers to explain important medical information."
    },

    {
        "Post-it note": "Health TV Channel",
        "Description": "Develop a TV channel dedicated to health information specifically designed for elderly viewers."
    },

    {
        "Post-it note": "Telephone Hotline",
        "Description": "Establish a telephone hotline where seniors can call to get their medical questions answered in real-time."
    },

    {
        "Post-it note": "Personal Health Coaches",
        "Description": "Assign health coaches who can regularly visit or call elderly patients to explain and discuss their medical information."
    },

    {
        "Post-it note": "Interactive Kiosks",
        "Description": "Set up interactive kiosks in hospitals and clinics where elderly patients can easily access medical information."
    },

    {
        "Post-it note": "Simplified Apps",
        "Description": "Develop smartphone apps with simplified interfaces focusing on the essential functions and easy navigation."
    },

    {
        "Post-it note": "Voice-Activated Assistants",
        "Description": "Use AI voice assistants like Alexa to answer medical questions and provide information."
    },

    {
        "Post-it note": "Memory Guides",
        "Description": "Develop personalized memory aids, such as color-coded charts, to help elderly patients remember their medication schedules."
    },

    {
        "Post-it note": "Buddy System",
        "Description": "Create a buddy system where tech-savvy youngsters can help teach elderly patients how to use digital tools for accessing medical information."
    },

    {
        "Post-it note": "Interactive Booklets",
        "Description": "Design interactive, tactile booklets that guide elderly patients through their medical information."
    },

    {
        "Post-it note": "Telephonic Alerts",
        "Description": "Provide automated phone alerts for medication reminders and upcoming appointments."
    },

    {
        "Post-it note": "Video Tutorials",
        "Description": "Create short, simple video tutorials explaining different aspects of medical care."
    },

    {
        "Post-it note": "Home Visits",
        "Description": "Organize teams for home visits where medical information can be explained in a face-to-face setting."
    },

    {
        "Post-it note": "User-Friendly Websites",
        "Description": "Create very simple websites with easy navigation and large text solely for medical information."

    },
    {
        "Post-it note": "Health Apps with Family Access",
        "Description": "Design apps where family members can help manage and access the elderly patient's medical information."

    },
    {
        "Post-it note": "Doctor's Notes in Plain Language",
        "Description": "Encourage doctors to provide patients with summaries of their visits in plain, non-medical language."

    },
    {
        "Post-it note": "Medication Packaging Redesign",
        "Description": "Work with pharmaceutical companies to redesign medication packaging to include simpler instructions and larger text."

    },
    {
        "Post-it note": "Pen-Pal Health Advisors",
        "Description": "Establish a pen-pal system where elderly patients can write to health advisors and receive written responses."

    },

    {
        "Post-it note": "Health Magazines for Elders",
        "Description": "Publish a magazine focused on elderly health issues with articles written in simple language."

    },

    {
        "Post-it note": "Local Health Fairs",
        "Description": "Organize local health fairs to provide in-person informational sessions."

    },

    {
        "Post-it note": "Weekly Radio Shows",
        "Description": "Produce weekly radio shows focused on elderly health topics."

    },

    {
        "Post-it note": "Personalized Health Diaries",
        "Description": "Provide personalized health diaries where elderly patients can keep track of their health information in a structured way."

    },

    {
        "Post-it note": "Large-Print Newsletters",
        "Description": "Send out monthly newsletters with large print discussing relevant health topics."

    },

    {
        "Post-it note": "Simplified Infographics",
        "Description": "Use infographics and visual summaries to explain complex medical topics."

    },

    {
        "Post-it note": "Health Topic Clubs",
        "Description": "Create clubs where elderly patients can join and discuss specific health topics in a social setting."

    },

    {
        "Post-it note": "Braille Health Guides",
        "Description": "For visually impaired elderly patients, offer Braille versions of medical guides."

    },

    {
        "Post-it note": "Simplified Financial Statements",
        "Description": "Provide simplified versions of medical bills and health insurance statements."

    },

    {
        "Post-it note": "Touchscreen Information Boards",
        "Description": "Install touchscreen information boards in clinics that provide simplified medical information."

    },

    {
        "Post-it note": "Inclusive Community Forums",
        "Description": "Hold community forums where elderly patients can ask questions and receive answers in a public setting."

    },

    {
        "Post-it note": "Collaborative Art Projects",
        "Description": "Use collaborative art projects to explain medical concepts and information in a more engaging manner."

    },

    {
        "Post-it note": "Cooking Classes on Nutrition",
        "Description": "Organize cooking classes that teach elderly patients about nutrition and healthy eating."


    },

    {
        "Post-it note": "Pictorial Health Calendars",
        "Description": "Distribute pictorial calendars that include health tips and reminders."

    },

    {
        "Post-it note": "Health Podcasts",
        "Description": "Produce podcasts focusing on health topics for elder listeners."

    },

    {
        "Post-it note": "Volunteer Readers",
        "Description": "Organize volunteer readers to go to elderly homes and read medical information aloud."


    },

    {
        "Post-it note": "Sign Language Videos",
        "Description": "Create videos with sign language for hearing-impaired elderly patients."

    },

    {
        "Post-it note": "Adaptive Technology Training",
        "Description": "Offer training sessions on adaptive technologies to help elderly patients use digital health resources."

    },

    {
        "Post-it note": "Personalized SMS Notifications",
        "Description": "Send personalized SMS notifications for health tips and appointments."

    },

    {
        "Post-it note": "Mobile Libraries on Health",
        "Description": "Establish mobile libraries that carry health books and brochures to elderly communities."

    },

    {
        "Post-it note": "Health Info Bulletin Boards",
        "Description": "Set up health information bulletin boards in elderly communities."

    },

    {
        "Post-it note": "Fitness and Health Classes",
        "Description": "Combine fitness classes with health education sessions."

    },

    {
        "Post-it note": "Gamified Health Apps",
        "Description": "Develop simple, gamified apps to engage elderly patients with their health."

    },

    {
        "Post-it note": "Family-Involved Health Stays",
        "Description": "Encourage family members to be more involved in elderly patients’ medical appointments and health management."

    },
    {
        "Post-it note": "Interactive TV Programs",
        "Description": "Create interactive TV programs where viewers can call or text in questions to health experts."

    },
    {
        "Post-it note": "Local Health Ambassadors",
        "Description": "Train local health ambassadors to disseminate medical information within elderly communities."

    },
    {
        "Post-it note": "Free Health Book Distributions",
        "Description": "Distribute free health guidebooks to elderly homes and community centers."

    },

    {
        "Post-it note": "Short Story-Based Learning",
        "Description": "Use short stories and anecdotes to explain medical information."

    },
    {
        "Post-it note": "Personalized Recorded Messages",
        "Description": "Send personalized recorded messages from doctors explaining important information directly to elderly patients."

    },

    {
       "Post-it note": "Visual Storytelling",
       "Description": "Utilize visuals like comics or illustrated stories to explain medical information. These can be provided in printed booklets. Visuals are often easier to understand than text-heavy documents, particularly for those who struggle with both technology and health literacy."

    },

    {
       "Post-it note": "Interactive Voice Response Systems",
       "Description": "Deploy a phone-based interactive voice response system that uses natural language processing to speak and understand simple questions about health conditions and treatments."

    },

    {
        "Post-it note": "Community Health Classes",
        "Description": "Organize free, community-based health education classes led by healthcare providers, designed to be easily understandable and engaging with interactive elements and hands-on learning."

    },

    {
       "Post-it note": "Health Ambassadors Program",
       "Description": "Train volunteers (perhaps other elderly individuals or family members) to act as health ambassadors who can visit homes and help explain medical information in person."

    },

    {
        "Post-it note": "Picture-Based Medication Guides",
        "Description": "Create medication guides that predominantly use pictures and symbols to explain what the medication is for, how to take it, and potential side effects."

    },

    {
        "Post-it note": "Simplified Radio Programs",
        "Description": "Air regular radio segments delivering simplified, easy-to-understand health information and advice, targeting elderly listeners."

    },

    {
       "Post-it note": "Pocket Health Reference Cards",
       "Description": "Distribute small, easily portable cards that summarize common health topics and instructions in highly simplified language and visuals."

    },

    {
       "Post-it note": "Health Games at Senior Centers",
       "Description": "Develop simple, non-digital games that can be played in senior centers to teach basic health concepts in a fun and engaging way."

    },

    {
       "Post-it note": "Audio Recordings from Doctors",
       "Description": "Allow doctors to record personalized audio messages for their elderly patients explaining their health issues and care plans in layman's terms."

    },

    {
        "Post-it note": "Health Literacy Theatre",
        "Description": "Create a traveling theatre group that performs plays and skits that educate on health topics in a fun, engaging, and memorable way."

    },

    {
         "Post-it note": "Voice-Activated Health Devices",
         "Description": "Introduce user-friendly, voice-activated health devices (like smart speakers) that can answer health queries and provide reminders about medications."

    },

    {
        "Post-it note": "Gamified Health Education Apps",
        "Description": "Develop mobile apps that use gamification to teach health literacy, with progress tracking and rewards to encourage engagement."

    },


    {
        "Post-it note": "Simplified Health Portals",
        "Description": "Create extremely easy-to-navigate health portals or apps with large icons, clear language, and audio support for accessing medical records and information."

    },

    {
        "Post-it note": "Virtual Reality Health Simulations",
        "Description": "Use VR headsets for immersive health education experiences, allowing users to virtually explore and understand different medical conditions and treatments."

    },

    {
        "Post-it note": "Digital Health Coaches",
        "Description": "Implement AI-driven digital health coaches that can chat with elderly patients through their smartphones or computers to provide guidance and information in simple terms."

    },

    {
        "Post-it note": "Interactive Webinars With Q&A",
        "Description": "Host live, interactive webinars on various health topics with an easy-to-use interface, allowing elderly participants to ask questions directly to health experts."

    },

    {
         "Post-it note": "Customized Health Apps",
         "Description": "Offer customizable health apps where users can choose their preferred way of receiving information, like text, audio, or video, with simplified content options."

    },

    {
        "Post-it note": "Virtual Peer Support Groups",
        "Description": "Create virtual support groups where elderly patients can discuss health topics with peers and moderators to help explain and reinforce understanding."

    },


    {
        "Post-it note": "AI-Generated Voice Summaries",
        "Description": "Develop AI systems that can generate simple voice summaries of complex medical documents, accessible through smartphones or smart speakers."

    },

    {
        "Post-it note": "Sponsored Tablet-Based Training Sessions",
        "Description": "Arrange for local tech retailers or community centers to sponsor training sessions teaching elderly patients how to use tablets to access health information."

    },

    {
       "Post-it note": "Printed Health Newsletters",
       "Description": "Send out monthly health newsletters that use clear, concise language to keep patients informed about various health topics and medical advances."

    },

    {
      "Post-it note": "Telephone Health Hotlines",
      "Description": "Establish toll-free health hotlines staffed by nurses or health educators who can answer questions in straightforward, jargon-free language."

    },

    {
       "Post-it note": "Health Education Radio Shows",
       "Description": "Develop specialized radio programs featuring expert interviews and Q&A segments focused on current health issues and preventive care tips."

    },

    {
       "Post-it note": "Community Bulletin Boards",
       "Description": "Set up bulletin boards in community centers or senior homes with rotating health topics, articles, and simple educational pamphlets."

    },


    {
        "Post-it note": "Printed Health Dictionaries",
        "Description": "Create printed health dictionaries that translate medical jargon into plain language, making it easier for patients to understand doctor’s instructions."


    },

    {
        "Post-it note": "Mail-Out Health Packets",
        "Description": "Organize a service that sends mail-out health information packets on a regular basis, curated to cover a range of essential topics."

    },

    {
        "Post-it note": "Interactive Workshops",
        "Description": "Host in-person workshops led by healthcare providers focusing on debunking medical myths, understanding prescriptions, and preventive health."

    },

    {
        "Post-it note": "Printed Step-by-Step Guides",
        "Description": "Develop printed materials that give step-by-step instructions for managing common health conditions or using medical devices."


    },

    {
        "Post-it note": "Health Information Fairs",
        "Description": "Organize local health fairs where various booths can provide easy-to-understand information on different health topics in a hands-on manner."


    },

    {
        "Post-it note": "Engaging Brochures",
        "Description": "Design engaging, easy-to-read brochures with high-quality visuals and simplified text to be distributed in doctor’s offices and hospitals."

    },


    {
        "Post-it note": "Telemedicine Platforms",
        "Description": "Expand telemedicine platforms to include not just consultations but also interactive health education sessions and Q&A features."

    },

    {
        "Post-it note": "Advanced Health Apps",
        "Description": "Develop comprehensive health apps that integrate medical records, personalized health advice, and easy communication with healthcare providers."


    },

    {
         "Post-it note": "Wearable Technology Integration",
         "Description": "Utilize wearable health tech to track vitals and offer real-time health tips and data analysis directly to the user’s smartphone."


    },
    {
        "Post-it note": "Smart Home Health Integration",
        "Description": "Integrate health monitoring and reminders into smart home systems, offering seamless health management for tech-savvy users."


    },
    {
        "Post-it note": "Online Health Communities",
        "Description": "Create or enhance platforms for online health communities where users can share experiences, tips, and advice with one another."



    },
    {
        "Post-it note": "Virtual Health Libraries",
        "Description": "Develop virtual health libraries featuring in-depth resources, articles, and videos on a wide range of health topics, accessible anytime online."



    },
    {
        "Post-it note": "AI Health Advisors",
        "Description": "Implement AI-driven health advisors that provide personalized health advice and help navigate complex medical issues through user-friendly interfaces."



    },
    {
        "Post-it note": "Interactive Learning Modules",
        "Description": "Create interactive online modules that users can go through at their own pace, offering in-depth, clear explanations on various health topics."



    },
    {
        "Post-it note": "Health Tracking Software",
        "Description": "Develop sophisticated health tracking software for personal computers and tablets to help users manage and understand their health data in detail."



    },
    {
        "Post-it note": "Digital Health Workshops",
        "Description": "Host live-streamed digital workshops and seminars that dive deep into complex health topics with opportunities for live Q&A with experts."



    },

]

# %%
for text in texts:
    print(text.keys())
# Out:
# dict_keys(['Post-it note', 'Description'])
# dict_keys(['Post-it note', 'Description'])
# dict_keys(['Post-it note', 'Description'])
# dict_keys(['Post-it note', 'Description'])
# dict_keys(['Post-it note', 'Description'])
# dict_keys(['Post-it note', 'Description'])
# dict_keys(['Post-it note', 'Description'])
# dict_keys(['Post-it note', 'Description'])
# dict_keys(['Post-it note', 'Description'])
# dict_keys(['Post-it note', 'Description'])
# dict_keys(['Post-it note', 'Description'])
# dict_keys(['Post-it note', 'Description'])
# dict_keys(['Post-it note', 'Description'])
# dict_keys(['Post-it note', 'Description'])
# dict_keys(['Post-it note', 'Description'])
# dict_keys(['Post-it note', 'Description'])
# dict_keys(['Post-it note', 'Description'])
# dict_keys(['Post-it note', 'Description'])
# dict_keys(['Post-it note', 'Description'])
# dict_keys(['Post-it note', 'Description'])
# dict_keys(['Post-it note', 'Description'])
# dict_keys(['Post-it note', 'Description'])
# ...

# %%
combined_texts = [f"Post-it note: {text['Post-it note']}\nDescription: {text['Description']}" for text in texts]

# %%
import openai
import os
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
import openai
import numpy as np

api_key = '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'

def get_openai_embedding(text, api_key):
    response = openai.Embedding.create(
        input=text,
        model="text-embedding-ada-002",  # Use the appropriate model name
        api_key=api_key
    )
    return response['data'][0]['embedding']

# Fetch embeddings for all texts
embeddings = [get_openai_embedding(text, api_key) for text in combined_texts]
embeddings_array = np.array(embeddings)

# %%
print(embeddings_array)
# Out:
# [[-0.02278991  0.02535834  0.0189829  ... -0.01595815 -0.01316156
#   -0.03345475]
#  [-0.03012508  0.03015076  0.02338353 ... -0.01029851 -0.01562755
#   -0.03685379]
#  [-0.00942447  0.025119    0.01107278 ... -0.01106632 -0.02179651
#   -0.06096818]
#  ...
#  [-0.0282183   0.01344103 -0.00079749 ... -0.01754146 -0.01232749
#   -0.05122263]
#  [-0.00975788  0.00824431  0.01686366 ... -0.01203495 -0.03059301
#   -0.01672971]
#  [-0.0140054   0.00606525  0.00600894 ... -0.01067961 -0.02105447
#   -0.02716278]]

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Reduce dimensions to 2D for visualization
pca = PCA(n_components=2)
reduced_embeddings = pca.fit_transform(embeddings_array)

# Plot the embeddings
plt.scatter(reduced_embeddings[:, 0], reduced_embeddings[:, 1])

# Annotate the points (optional)
for i, text in enumerate(texts):
    plt.annotate(f"note {i+1}", (reduced_embeddings[i, 0], reduced_embeddings[i, 1]))

plt.title("2D Visualization of Embeddings")
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.show()

# %%
import pandas as pd
from sklearn.decomposition import PCA
from scipy.spatial.distance import cdist
pca = PCA(n_components=2)
pca_result = pca.fit_transform(embeddings_array)

# Create a DataFrame for plotting
df = pd.DataFrame(pca_result, columns=['PCA1', 'PCA2'])
df['label'] = [f"Note {i+1}" for i in range(len(embeddings_array))]

# Calculate mean and standard deviation of embeddings
mean_vector = np.mean(embeddings_array, axis=0)
std_vector = np.std(embeddings_array, axis=0)

# Perform PCA on mean and standard deviation vectors
mean_pca = pca.transform([mean_vector])[0]
std_pca = pca.transform([std_vector])[0]

# Calculate the radius for the circle (use norm of std_pca to get a single radius value)
radius = np.linalg.norm(std_pca) * 2

# Calculate distances between points in PCA space
distances = cdist(pca_result, pca_result)

# Find nearest prior point for each point
nearest_prior_indices = []
nearest_prior_distances = []
for i in range(1, len(distances)):
    prior_distances = distances[i, :i]
    nearest_prior_idx = np.argmin(prior_distances)
    nearest_prior_distances.append(np.min(prior_distances))
    nearest_prior_indices.append(nearest_prior_idx)

# Add a zero for the first point which has no prior points
nearest_prior_distances = [0] + nearest_prior_distances

# Add the nearest prior distances to the DataFrame
df['nearest_prior_distance'] = nearest_prior_distances

# Plotting
plt.figure(figsize=(12, 10))
plt.scatter(df['PCA1'], df['PCA2'], alpha=0.7, label='Post-it notes')

# %%
pca = PCA(n_components=2)
vectors_pca = pca.fit_transform(embeddings_array)

# Create DataFrame
df = pd.DataFrame(vectors_pca, columns=['PCA1', 'PCA2'])
df['label'] = [f"Note {i+1}" for i in range(len(combined_texts))]

# Calculate distances between PCA-transformed vectors
distances = cdist(vectors_pca, vectors_pca)

# Initialize lists for nearest prior indices and distances
nearest_prior_indices = []
nearest_prior_distances = []

# Find nearest prior points
for i in range(1, len(distances)):
    prior_distances = distances[i, :i]
    nearest_prior_idx = np.argmin(prior_distances)
    nearest_prior_indices.append(nearest_prior_idx)
    nearest_prior_distances.append(np.min(prior_distances))

# Update the DataFrame with the nearest prior distances
df['nearest_prior_distance'] = [0] + nearest_prior_distances  # First point has no prior point

# Plotting
plt.figure(figsize=(10, 8))
plt.scatter(df['PCA1'], df['PCA2'], alpha=0.5, label='Post-it Notes')

# Annotate each point with its label
for i, label in enumerate(df['label']):
    plt.annotate(label, (df['PCA1'].iloc[i], df['PCA2'].iloc[i]))

# Draw lines between each point and its nearest prior point
for i in range(1, len(df)):
    prior_idx = nearest_prior_indices[i-1]  # Get the nearest prior index
    plt.plot(
        [df['PCA1'].iloc[i], df['PCA1'].iloc[prior_idx]],
        [df['PCA2'].iloc[i], df['PCA2'].iloc[prior_idx]],
        'r-',
        linewidth=1
    )

# Add titles, labels, and legend
plt.title('2D PCA Visualization of Text Embeddings with Nearest Prior Point Lines')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.grid(True)
plt.show()

# Print the DataFrame with nearest prior distances
print(df[['label', 'nearest_prior_distance']])
# Out:
#       label  nearest_prior_distance
# 0    Note 1                0.000000
# 1    Note 2                0.116613
# 2    Note 3                0.098893
# 3    Note 4                0.247994
# 4    Note 5                0.155322
# ..      ...                     ...
# 85  Note 86                0.014498
# 86  Note 87                0.012076
# 87  Note 88                0.010117
# 88  Note 89                0.007228
# 89  Note 90                0.024246
#
# [90 rows x 2 columns]

# %%
for i, label in enumerate(df['label']):
    plt.annotate(label, (df['PCA1'].iloc[i], df['PCA2'].iloc[i]), fontsize=8)

# Plot the mean vector
plt.scatter(mean_pca[0], mean_pca[1], color='red', label='Mean vector')

# Plot standard deviation ellipse
from matplotlib.patches import Ellipse
ellipse = Ellipse(xy=(mean_pca[0], mean_pca[1]), width=radius, height=radius,
                  edgecolor='blue', facecolor='none', linestyle='--', linewidth=2, label='Std deviation circle')
plt.gca().add_patch(ellipse)

# Draw lines to nearest prior points
for i, prior_idx in enumerate(nearest_prior_indices, start=1):
    plt.plot(
        [df['PCA1'].iloc[i], df['PCA1'].iloc[prior_idx]],
        [df['PCA2'].iloc[i], df['PCA2'].iloc[prior_idx]],
        'r-',
        linewidth=1
    )

plt.title('2D PCA Visualization of Text Embeddings with Mean, Std Deviation, and Nearest Prior Point Lines')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.grid(True)
plt.show()

# Print DataFrame with nearest prior distances
print(df[['label', 'nearest_prior_distance']])
# Out:
#       label  nearest_prior_distance
# 0    Note 1                0.000000
# 1    Note 2                0.116613
# 2    Note 3                0.098893
# 3    Note 4                0.247994
# 4    Note 5                0.155322
# ..      ...                     ...
# 85  Note 86                0.014498
# 86  Note 87                0.012076
# 87  Note 88                0.010117
# 88  Note 89                0.007228
# 89  Note 90                0.024246
#
# [90 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
scaler = StandardScaler()
scaled_embeddings = scaler.fit_transform(embeddings_array)
pca = PCA(n_components=2)
pca_result = pca.fit_transform(scaled_embeddings)

# Create DataFrame for plotting
df = pd.DataFrame(pca_result, columns=['PCA1', 'PCA2'])
df['label'] = [f"Post-it note {i+1}" for i in range(len(embeddings_array))]

# Calculate distances between PCA-reduced vectors
distances = cdist(pca_result, pca_result)

# Find nearest prior distances
nearest_prior_indices = []
nearest_prior_distances = []

for i in range(1, len(distances)):
    prior_distances = distances[i, :i]
    nearest_prior_idx = np.argmin(prior_distances)
    nearest_prior_distances.append(np.min(prior_distances))
    nearest_prior_indices.append(nearest_prior_idx)

# Add zero for the first point as it has no prior point
df['nearest_prior_distance'] = [0] + nearest_prior_distances

# Plotting the distance to nearest prior point
plt.figure(figsize=(10, 6))
plt.plot(range(len(df)), df['nearest_prior_distance'], marker='o', linestyle='-', color='b')
plt.title('Distance to Nearest Prior Point for Each Post-it Note')
plt.xlabel('Post-it Note Index')
plt.ylabel('Distance to Nearest Prior Point')
plt.grid(True)
plt.show()

# Print the DataFrame with labels and nearest prior distances
print(df[['label', 'nearest_prior_distance']])
# Out:
#               label  nearest_prior_distance
# 0    Post-it note 1                0.000000
# 1    Post-it note 2               11.014689
# 2    Post-it note 3                9.066085
# 3    Post-it note 4               22.590517
# 4    Post-it note 5               14.010864
# ..              ...                     ...
# 85  Post-it note 86                2.190760
# 86  Post-it note 87                1.516788
# 87  Post-it note 88                2.685679
# 88  Post-it note 89                1.033389
# 89  Post-it note 90                3.884364
#
# [90 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'df' DataFrame is defined and contains 'label' and 'nearest_prior_distance' columns
# Ensure nearest_prior_distances is correctly indexed to match df['label'][1:]

plt.figure(figsize=(12, 8))  # Increased figure size for better label visibility
plt.plot(df['label'][1:], df['nearest_prior_distance'][1:], marker='o', linestyle='-', color='b')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.title('Distance to Nearest Prior Point for Each Post-it Note')
plt.xlabel('Post-it Note')
plt.ylabel('Distance to Nearest Prior Point')
plt.grid(True)
plt.tight_layout()  # Adjust layout to fit rotated labels
plt.show()

# Print the DataFrame with labels and nearest prior distances
print(df[['label', 'nearest_prior_distance']])
# Out:
#               label  nearest_prior_distance
# 0    Post-it note 1                0.000000
# 1    Post-it note 2               11.014689
# 2    Post-it note 3                9.066085
# 3    Post-it note 4               22.590517
# 4    Post-it note 5               14.010864
# ..              ...                     ...
# 85  Post-it note 86                2.190760
# 86  Post-it note 87                1.516788
# 87  Post-it note 88                2.685679
# 88  Post-it note 89                1.033389
# 89  Post-it note 90                3.884364
#
# [90 rows x 2 columns]

# %%
window_size = 3
df['moving_average'] = df['nearest_prior_distance'].rolling(window=window_size).mean()

# Plotting
plt.figure(figsize=(12, 8))  # Adjusted figure size for clarity
plt.plot(df['label'][1:], df['nearest_prior_distance'][1:], marker='o', linestyle='-', color='b', label='Distance to Nearest Prior Point')
plt.plot(df['label'][1:], df['moving_average'][1:], linestyle='-', color='r', label='Moving Average (window={})'.format(window_size))
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.title('Distance to Nearest Prior Point for Each Post-it Note with Moving Average')
plt.xlabel('Post-it Note')
plt.ylabel('Distance to Nearest Prior Point')
plt.legend()
plt.grid(True)
plt.tight_layout()  # Adjust layout to fit rotated labels
plt.show()

# Print the DataFrame with nearest prior distances and moving average
print(df[['label', 'nearest_prior_distance', 'moving_average']])
# Out:
#               label  nearest_prior_distance  moving_average
# 0    Post-it note 1                0.000000             NaN
# 1    Post-it note 2               11.013147             NaN
# 2    Post-it note 3                9.066678        6.693275
# 3    Post-it note 4               22.590563       14.223462
# 4    Post-it note 5               14.011471       15.222904
# ..              ...                     ...             ...
# 85  Post-it note 86                2.191563        3.009735
# 86  Post-it note 87                1.517174        2.192690
# 87  Post-it note 88                2.687553        2.132097
# 88  Post-it note 89                1.034113        1.746280
# 89  Post-it note 90                3.883997        2.535221
#
# [90 rows x 3 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' DataFrame is defined and contains 'label' and 'nearest_prior_distance' columns

# Calculate the moving average with a window size of 5
window_size = 5
df['moving_average'] = df['nearest_prior_distance'].rolling(window=window_size).mean()

# Plotting
plt.figure(figsize=(12, 8))  # Adjusted figure size for clarity
plt.plot(df['label'][1:], df['nearest_prior_distance'][1:], marker='o', linestyle='-', color='b', label='Distance to Nearest Prior Point')
plt.plot(df['label'][1:], df['moving_average'][1:], linestyle='-', color='r', label='Moving Average (window={})'.format(window_size))

# Adding a vertical red constraint line at "Post-it note 50" and label it as Quadrant 1 if it exists
if 'Post-it note 50' in df['label'].values:
    note_index = df[df['label'] == 'Post-it note 50'].index[0] - 1  # Adjust for 0-based index
    plt.axvline(x=note_index, color='red', linestyle='--', linewidth=2, label='Quadrant 1 at Post-it note 50')
else:
    print("Post-it note 50 not found in the DataFrame")

# Adding vertical constraint lines every 10 notes after 50 and labeling them as Quadrant 2, Quadrant 3, etc.
quadrant_counter = 2
for i in range(60, len(df), 10):  # Starting from 60 because 50 is already Quadrant 1
    plt.axvline(x=i, color='green', linestyle='--', linewidth=2, label=f'Quadrant {quadrant_counter}')
    quadrant_counter += 1

plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.title('Distance to Nearest Prior Point for Each Post-it Note with Moving Average\n 2 x 2 matrix constraints')
plt.xlabel('Post-it Note')
plt.ylabel('Distance to Nearest Prior Point')
plt.legend()
plt.grid(True)
plt.tight_layout()  # Adjust layout to fit rotated labels
plt.show()

# Print the DataFrame with nearest prior distances and moving average
print(df[['label', 'nearest_prior_distance', 'moving_average']])
# Out:
#               label  nearest_prior_distance  moving_average
# 0    Post-it note 1                0.000000             NaN
# 1    Post-it note 2               11.013147             NaN
# 2    Post-it note 3                9.066678             NaN
# 3    Post-it note 4               22.590563             NaN
# 4    Post-it note 5               14.011471       11.336372
# ..              ...                     ...             ...
# 85  Post-it note 86                2.191563        2.252944
# 86  Post-it note 87                1.517174        2.184725
# 87  Post-it note 88                2.687553        2.646786
# 88  Post-it note 89                1.034113        2.059947
# 89  Post-it note 90                3.883997        2.262880
#
# [90 rows x 3 columns]
